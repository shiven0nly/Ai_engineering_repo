# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: str

# %%
# integers
runs = [13,24,56,78,100]

runs_ser = pd.Series(runs)

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Shiven')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Shiven, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks = pd.Series(marks,name='shiv')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: shiv, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks.size
# Out:
# 4

# %%
# dtype
marks.dtype
# Out:
# dtype('int64')

# %%
# name
marks.name
# Out:
# 'shiv'

# %%
# is_unique
marks.is_unique
# Out:
# True

# %%
#is_unique
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='str')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
subs = pd.read_csv('./datasets_1/subs.csv').squeeze()
# with squeeze it wont convert into to series.
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('./datasets_1/kohli_ipl.csv',index_col='match_no').squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('./datasets_1/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
movies.sample(5)
# Out:
# movie
# Bhaag Johnny            Kunal Khemu
# Khuda Kasam              Sunny Deol
# Bheja Fry 2            Vinay Pathak
# Evening Shadows    Mona Ambegaonkar
# Calcutta Mail           Anil Kapoor
# Name: lead, dtype: str

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values -> inplace
vk.sort_values(ascending=False) # for descending order
# vk.sort_values() # for ascending order
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
# sort_index -> inplace -> movies
movies.sort_index(ascending=False,inplace=True)
# movies get sorted according to the index, as ascending=false, then it will make the series in descending order. and inplace=True, then it is permanentaly changed.

# %%
movies # if inplace=True, then changes are permanant in the original series..
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: str

# %%
vk.sort_values(inplace=True)

# %%
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# ### Series Maths Methods

# %%
# count
vk.count()
# Out:
# np.int64(215)

# %%
# sum & product
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: str
# 62.6750230372527
# 688.0024777222343

# %%
# min/max
subs.max()
# Out:
# np.int64(396)

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
# negative indexing
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Shive\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 # negative indexing
# ----> 2 x[-1]
#
# File c:\Users\Shive\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
# ...

# %%
movies[3] # we cant print the particular with this type of indexing using in lists and tuples
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Shive\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
vk[-1] # we cant use negative indexing in this.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Shive\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2761 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
marks[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Shive\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# slicing
vk[5:16]
# Out:
# match_no
# 207    0
# 135    0
# 130    0
# 211    0
# 106    1
# 204    1
# 113    1
# 77     1
# 1      1
# 5      1
# 75     1
# Name: runs, dtype: int64

# %%
# negative slicing
vk[-5:] # last 5 movies
# Out:
# match_no
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, dtype: int64

# %%
movies[::2] # with one jump, alternate movie
# Out:
# movie
# Zor Lagaa Ke...Haiya!         Meghan Jadhav
# Zindagi Tere Naam        Mithun Chakraborty
# Zindagi 50-50                   Veena Malik
# Zinda (film)                    Sanjay Dutt
# Zid (2014 film)              Mannara Chopra
#                                 ...
# 3 Storeys                       Aisha Ahmed
# 3 Deewarein                Naseeruddin Shah
# 22 Yards                        Barun Sobti
# 1971 (2007 film)             Manoj Bajpayee
# 1920: London                  Sharman Joshi
# Name: lead, Length: 750, dtype: str

# %%
# fancy indexing
vk[[1,3,4,5]] # its same like python
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks[1] = 100 # it will append in series
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# 1          100
# Name: shiv, dtype: int64

# %%
# what if an index does not exist
# if we only write marks['evs'] it will give the error while reading
marks['evs'] = 100 # it will append

# %%
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# 1          100
# evs        100
# Name: shiv, dtype: int64

# %%
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# slicing
runs_ser[2:4] = [100,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing -> changing particular indexes
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)                Alia Bhatt
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(marks)
# Out:
# [67, 57, 89, 100, 100, 100]

# %%
list(movies)
# Out:
# ['Meghan Jadhav',
#  'Darsheel Safary',
#  'Mithun Chakraborty',
#  'Hrithik Roshan',
#  'Veena Malik',
#  'Sushmita Sen',
#  'Sanjay Dutt',
#  'Vivek Oberoi',
#  'Mannara Chopra',
#  'Shah Rukh Khan',
#  'Emraan Hashmi',
#  'Vinod Acharya',
#  'Ajay Devgn',
#  'Ajay Devgn',
#  'Jeetendra',
#  'Salman Khan',
#  'Ajay Devgn',
#  'Paresh Rawal',
#  'Jackky Bhagnani',
#  'Vardhan Puri',
#  'Anupam Kher',
#  'Shah Rukh Khan',
#  'Anya Anand',
#  'Ranbir Kapoor',
#  'Gavie Chahal',
#  'Anshuman Jha',
#  'Deepshika Nagpal',
#  'Tusshar Kapoor',
#  'Rekha',
#  'Dharmendra',
#  'Nafisa Ali',
#  'Arjun Rampal',
#  'Prisha Aneja',
#  'Siddhanth Kapoor',
#  'Indrapal Ahuja',
#  'Sharman Joshi',
#  'Sikander Kher',
#  'Kangana Ranaut',
#  'Emraan Hashmi',
#  'Harman Baweja',
#  'Manu Rishi Chadha',
#  'Boman Irani',
#  'Shreyas Talpade',
#  'Anil Kapoor',
#  'Arshad Warsi',
#  'Akshay Kumar',
#  'Diganth',
#  'Nana Patekar',
#  'Gurdas Maan',
#  'Sharman Joshi',
#  'Amitabh Bachchan',
# ...

# %%
dict(marks) # we typecast the marks series in a dictionery
# Out:
# {'maths': np.int64(67),
#  'english': np.int64(57),
#  'science': np.int64(89),
#  'hindi': np.int64(100),
#  1: np.int64(100),
#  'evs': np.int64(100)}

# %%
dict(movies)
# Out:
# {'Zor Lagaa Ke...Haiya!': 'Meghan Jadhav',
#  'Zokkomon': 'Darsheel Safary',
#  'Zindagi Tere Naam': 'Mithun Chakraborty',
#  'Zindagi Na Milegi Dobara': 'Hrithik Roshan',
#  'Zindagi 50-50': 'Veena Malik',
#  'Zindaggi Rocks': 'Sushmita Sen',
#  'Zinda (film)': 'Sanjay Dutt',
#  'Zila Ghaziabad': 'Vivek Oberoi',
#  'Zid (2014 film)': 'Mannara Chopra',
#  'Zero (2018 film)': 'Shah Rukh Khan',
#  'Zeher': 'Emraan Hashmi',
#  'Zed Plus': 'Vinod Acharya',
#  'Zameer: The Fire Within': 'Ajay Devgn',
#  'Zameen (2003 film)': 'Ajay Devgn',
#  'Zamaanat': 'Jeetendra',
#  'Yuvvraaj': 'Salman Khan',
#  'Yuva': 'Ajay Devgn',
#  'Yun Hota Toh Kya Hota': 'Paresh Rawal',
#  'Youngistaan': 'Jackky Bhagnani',
#  'Yeh Saali Aashiqui': 'Vardhan Puri',
#  'Yeh Mera India': 'Anupam Kher',
#  'Yeh Lamhe Judaai Ke': 'Shah Rukh Khan',
#  'Yeh Khula Aasmaan': 'Anya Anand',
#  'Yeh Jawaani Hai Deewani': 'Ranbir Kapoor',
#  'Yeh Hai India': 'Gavie Chahal',
#  'Yeh Hai Bakrapur': 'Anshuman Jha',
# ...

# %%
# membership operator
# checking
'2 States (2014 film)' in movies
# Out:
# True

# %%
'Alia Bhatt' in movies.values
# Out:
# True

# %%
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)                Alia Bhatt
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: str

# %%
'Arjun Kapoor' in movies.values
# Out:
# True

# %%
# looping
for i in movies.index:
  print(i)
# Out:
# Zor Lagaa Ke...Haiya!
# Zokkomon
# Zindagi Tere Naam
# Zindagi Na Milegi Dobara
# Zindagi 50-50
# Zindaggi Rocks
# Zinda (film)
# Zila Ghaziabad
# Zid (2014 film)
# Zero (2018 film)
# Zeher
# Zed Plus
# Zameer: The Fire Within
# Zameen (2003 film)
# Zamaanat
# Yuvvraaj
# Yuva
# Yun Hota Toh Kya Hota
# Youngistaan
# Yeh Saali Aashiqui
# Yeh Mera India
# Yeh Lamhe Judaai Ke
# Yeh Khula Aasmaan
# Yeh Jawaani Hai Deewani
# Yeh Hai India
# Yeh Hai Bakrapur
# Yeh Dooriyan
# Yeh Dil
# Yatra (2007 film)
# Yamla Pagla Deewana: Phir Se
# Yamla Pagla Deewana
# Yakeen (2005 film)
# Yadvi – The Dignified Princess
# Yaaram (2019 film)
# Ya Rab
# Xcuse Me
# Woodstock Villa
# Woh Lamhe...
# Why Cheat India
# What's Your Raashee?
# What the Fish
# Well Done Abba
# Welcome to Sajjanpur
# Welcome Back (film)
# Welcome 2 Karachi
# Welcome (2007 film)
# Wedding Pullav
# Wedding Anniversary
# Waris Shah: Ishq Daa Waaris
# War Chhod Na Yaar
# Waqt: The Race Against Time
# Wanted (2009 film)
# Wake Up Sid
# ...

# %%
for i in subs:
    print(i)
# Out:
# 48
# 57
# 40
# 43
# 44
# 46
# 33
# 40
# 44
# 74
# 49
# 56
# 49
# 42
# 39
# 44
# 54
# 51
# 40
# 37
# 40
# 45
# 50
# 56
# 35
# 49
# 46
# 88
# 61
# 42
# 56
# 50
# 50
# 49
# 76
# 123
# 108
# 110
# 56
# 62
# 65
# 66
# 33
# 66
# 82
# 126
# 109
# 88
# 83
# 108
# 101
# 128
# 111
# 96
# 101
# 99
# 105
# 72
# 93
# 76
# 104
# 70
# 80
# 99
# 104
# 136
# 115
# 123
# 112
# 145
# 87
# 84
# 92
# 80
# 70
# 70
# 132
# 123
# 98
# 96
# 88
# 86
# 92
# 92
# 110
# 120
# 105
# 72
# 84
# 90
# 78
# 81
# 89
# 89
# 93
# 86
# 95
# 83
# 72
# 87
# 100
# 72
# 79
# 67
# 71
# 90
# 77
# 100
# 88
# 65
# 95
# 78
# 89
# 96
# 81
# 105
# 80
# 66
# 73
# 68
# 159
# 90
# 83
# 76
# 77
# 66
# 64
# 85
# 136
# 135
# 71
# 79
# 75
# 72
# 78
# 109
# 93
# 84
# 74
# 87
# 128
# 105
# 105
# 82
# 86
# 100
# 88
# 104
# 87
# 119
# 118
# 97
# 114
# 117
# 102
# 101
# 96
# 90
# 114
# 118
# 113
# 123
# 129
# 140
# 180
# 225
# 249
# 265
# 306
# 261
# 222
# 170
# 160
# 114
# 175
# 170
# 115
# 152
# 105
# 105
# 93
# 110
# 102
# 136
# 76
# 105
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 + marks
# Out:
# maths      167
# english    157
# science    189
# hindi      200
# 1          200
# evs        200
# Name: shiv, dtype: int64

# %%
# Relational Operators

vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0]
# Out:
# match_no
# 8      0
# 87     0
# 93     0
# 91     0
# 206    0
# 207    0
# 135    0
# 130    0
# 211    0
# Name: runs, dtype: int64

# %%
# to count the number of matches where virat kohli scored 0 , we simply add .size in last
vk[vk==0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
import matplotlib as plot
subs.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: >

# %%
# for bar chart
subs.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Subscribers gained'>

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
subs = pd.read_csv('./datasets_1/subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('./datasets_1/kohli_ipl.csv',index_col='match_no').squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('./datasets_1/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 1884

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 594

# %%
# between
vk[vk.between(51,99)].size
# Out:
# 43

# %%
# clip
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: str

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna to fillup the missing values according to mean, median
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: str

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: str

# %%
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
# copy

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head()

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 1

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
